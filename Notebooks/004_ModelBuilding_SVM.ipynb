# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
X = np.load('/content/drive/MyDrive/Gender Classification/data_pca_X.npz')
X_train = X['train']
X_test = X['test']

# %%
y = np.load('/content/drive/MyDrive/Gender Classification/data_y.npz')
y_train = y['train']
y_test = y['test']

# %% [markdown]
# ### Support Vector Machine (SVM)

# %%
model_svc = SVC(probability=True)

param_grid = {'C':[0.5,1,10,20,30,50],
             'kernel':['rbf','poly','sigmoid'],
             'gamma':[0.1,0.05,0.01,0.001,0.002,0.005]}

# %%
svc_grid = GridSearchCV(model_svc,param_grid=param_grid,scoring='accuracy',cv=3,verbose=1)
svc_grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 108 candidates, totalling 324 fits
# GridSearchCV(cv=3, estimator=SVC(probability=True),
#              param_grid={'C': [0.5, 1, 10, 20, 30, 50],
#                          'gamma': [0.1, 0.05, 0.01, 0.001, 0.002, 0.005],
#                          'kernel': ['rbf', 'poly', 'sigmoid']},
#              scoring='accuracy', verbose=1)

# %%
svc_grid.best_params_
# Out:
# {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
model_final = svc_grid.best_estimator_

# %%
import pickle
pickle.dump(model_final,open('/content/drive/MyDrive/Gender Classification/model_svm.pickle','wb'))

# %% [markdown]
# ### Model Evaluation

# %%
score_cnn = model_cnn.evaluate(x=testing_set, verbose=0)
print('CNN Test accuracy:', score[1])
print('CNN Test AUC:', score[2])
# Out:
# CNN Test accuracy: 0.8793418407440186
# CNN Test AUC: 0.9290169477462769

# %%
from sklearn.metrics import roc_auc_score, accuracy_score
y_pred = model_final.predict(X_test)


print('SVM Test accuracy:', accuracy_score(y_test, y_pred))
print('SVM Test AUC:', roc_auc_score(y_test,y_pred))
# Out:
# SVM Test accuracy: 0.8837528604118993
# SVM Test AUC: 0.8836545190018074
